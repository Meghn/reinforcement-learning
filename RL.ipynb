# %% [markdown]
# # Import Dependencies

# %%
# %pip install stable-baselines3
# Out:
# Requirement already satisfied: stable-baselines3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.3.2)
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3)
#   Using cached gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.20 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stable-baselines3) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: cloudpickle in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stable-baselines3) (3.0.0)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from stable-baselines3) (3.9.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3) (3.13.1)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3) (2024.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Users/meghnapusala/Library/Python/3.12/lib/python/site-packages (from matplotlib->stable-baselines3) (23.2)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->stable-baselines3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/meghnapusala/Library/Python/3.12/lib/python/site-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->stable-baselines3) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/meghnapusala/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Using cached gymnasium-0.29.1-py3-none-any.whl (953 kB)
# Installing collected packages: gymnasium
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.0.0a2
#     Uninstalling gymnasium-1.0.0a2:
#       Successfully uninstalled gymnasium-1.0.0a2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# shimmy 2.0.0 requires gymnasium>=1.0.0a1, but you have gymnasium 0.29.1 which is incompatible.
# Successfully installed gymnasium-0.29.1
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install gym
# %pip install gym[classic_control]
# Out:
# Requirement already satisfied: gym in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gym) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gym) (0.0.8)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# zsh:1: no matches found: gym[classic_control]
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import gym # for openai gym
from stable_baselines3 import PPO # Algorithm
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %% [markdown]
# # Load Environment

# %%
env_name = 'CartPole-v0'

# %%
env = gym.make(env_name)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0
    while not done:
        env.render() # Graphical representation of the episode.
        action = env.action_space.sample() # Generate a random action
        next_state, reward, done, info, _ = env.step(action)
        score += reward    
    print(f"Episode: {episode}, Score: {score}")
env.close()
# Out:
# Episode: 1, Score: 11.0
# Episode: 2, Score: 16.0
# Episode: 3, Score: 40.0
# Episode: 4, Score: 20.0
# Episode: 5, Score: 18.0
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/envs/classic_control/cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v0", render_mode="rgb_array")
#   gym.logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):

# %% [markdown]
# ## Understanding The Environment

# %% [markdown]
# **Episodes**
# Think of an episode as one full game within the environment.
# Some Environments have a fixed episode length e.g. CartPole which is 200 frames. Others are continuous. e.g. Breakout, play until you run out of lives.

# %%
env.reset()
# Out:
# (array([ 0.04945291, -0.00088456,  0.00082668,  0.0273103 ], dtype=float32),
#  {})

# %%
env.action_space
# Out:
# Discrete(2)

# %%
env.observation_space
# Out:
# Box([-4.8000002e+00 -3.4028235e+38 -4.1887903e-01 -3.4028235e+38], [4.8000002e+00 3.4028235e+38 4.1887903e-01 3.4028235e+38], (4,), float32)

# %%
env.step(1)
# Out:
# (array([ 0.04943522,  0.19422552,  0.00137288, -0.26511168], dtype=float32),
#  1.0,
#  False,
#  False,
#  {})

# %% [markdown]
# # Train RL Model

# %%
# %pip install 'shimmy>=0.2.1'
# Out:
# Requirement already satisfied: shimmy>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from shimmy>=0.2.1) (1.26.4)
# Collecting gymnasium>=1.0.0a1 (from shimmy>=0.2.1)
#   Using cached gymnasium-1.0.0a2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gymnasium>=1.0.0a1->shimmy>=0.2.1) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gymnasium>=1.0.0a1->shimmy>=0.2.1) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gymnasium>=1.0.0a1->shimmy>=0.2.1) (0.0.4)
# Using cached gymnasium-1.0.0a2-py3-none-any.whl (954 kB)
# Installing collected packages: gymnasium
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 0.29.1
#     Uninstalling gymnasium-0.29.1:
#       Successfully uninstalled gymnasium-0.29.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# stable-baselines3 2.3.2 requires gymnasium<0.30,>=0.28.1, but you have gymnasium 1.0.0a2 which is incompatible.
# Successfully installed gymnasium-1.0.0a2
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
log_path = os.path.join('training', 'logs')
if not os.path.exists(log_path):
    os.makedirs(log_path)

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda: env]) # Wrapped the environment in a vectorization
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path) 
#  Policy(MLP=Neural network), env,
# Out:
# Using cpu device
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %% [markdown]
# **Policies**
# Policy is like the rule which tells the agent how to operate in the environment
# SB3 has three policy types: MlpPolicy, CnnPolicy and MultiInputPPolicy.

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to training/logs/PPO_4
# -----------------------------
# | time/              |      |
# |    fps             | 5290 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3466        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005557725 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.209       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00667    |
# |    value_loss           | 6.2         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3140        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008519561 |
# |    clip_fraction        | 0.066       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.524      |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.434       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00672    |
# |    value_loss           | 4.05        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3008         |
# |    iterations           | 4            |
# |    time_elapsed         | 2            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0027880552 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.535       |
# |    explained_variance   | -0.0137      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.238        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.000384    |
# |    value_loss           | 2.84         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2929         |
# |    iterations           | 5            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0008087945 |
# |    clip_fraction        | 0.00879      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.508       |
# |    explained_variance   | 0.0123       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.2          |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0025      |
# |    value_loss           | 21.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2880         |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0064318283 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.488       |
# |    explained_variance   | -2.61        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.24         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00056     |
# |    value_loss           | 1.63         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2846       |
# |    iterations           | 7          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.00680436 |
# |    clip_fraction        | 0.045      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.498     |
# |    explained_variance   | 0.213      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.105      |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.00316   |
# |    value_loss           | 0.729      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2822        |
# |    iterations           | 8           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003068327 |
# |    clip_fraction        | 0.0134      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.494      |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0873      |
# |    n_updates            | 170         |
# |    policy_gradient_loss | 0.000139    |
# |    value_loss           | 0.424       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2800         |
# |    iterations           | 9            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0049082427 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.49        |
# |    explained_variance   | 0.831        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0913       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00568     |
# |    value_loss           | 0.344        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2783         |
# |    iterations           | 10           |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0024383985 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.473       |
# |    explained_variance   | 0.0254       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0496       |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 0.199        |
# ------------------------------------------

# %% [markdown]
# # Save & Reload Model

# %%
model_path = os.path.join('training', 'saved models')
PPO_Path = os.path.join(model_path,'PPO_Model_Cartpole')
if not os.path.exists(model_path):
    os.makedirs(model_path)

# %%
model.save(PPO_Path)

# %%
del model

# %%
model = PPO.load(PPO_Path, env=env)

# %% [markdown]
# # Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (200.0, 0.0)

# %% [markdown]
# PPO model would be considered solved if the evaluation metric is 200 or higher. Different Algorithms have different evaluation metrics to consider it solved.

# %% [markdown]
# **CartPole Reward**
# Reward for CartPole is calculated a s1 point for every step that the pole remains upright(with a max of 200 steps)
# If the pole is more than 15 degrees from the vertical or the cart moves more than 2.4 units from the center the episode ends.

# %%
env.close()

# %% [markdown]
# # Test Model

# %%
# obs = env.reset()
# while True:
#     action, _states = model.predict(obs)
#     obs, rewards, done, info = env.step(action)
#     env.render()
#     if done: 
#         print('info', info)
#         break
# Out:
# info [{'TimeLimit.truncated': True, 'terminal_observation': array([ 0.10402902, -0.01270733,  0.02109799, -0.24954855], dtype=float32)}]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0
    while not done:
        env.render() # Graphical representation of the episode.
        action, _ = model.predict(obs) # Generate a random action
        obs, reward, done, info = env.step(action)
        score += reward    
    print(f"Episode: {episode}, Score: {score}")
# Out:
# Episode: 1, Score: [200.]
# Episode: 2, Score: [200.]
# Episode: 3, Score: [200.]
# Episode: 4, Score: [200.]
# Episode: 5, Score: [200.]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")

# %%
env.close()

# %% [markdown]
# ### Steps:

# %%
obs = env.reset()

# %%
action, _ = model.predict(obs)

# %%
model.predict??
# Out:
# Signature:
# model.predict(
#     observation: Union[numpy.ndarray, Dict[str, numpy.ndarray]],
#     state: Optional[Tuple[numpy.ndarray, ...]] = None,
#     episode_start: Optional[numpy.ndarray] = None,
#     deterministic: bool = False,
# ) -> Tuple[numpy.ndarray, Optional[Tuple[numpy.ndarray, ...]]]
# Source:
#     def predict(
#         self,
#         observation: Union[np.ndarray, Dict[str, np.ndarray]],
#         state: Optional[Tuple[np.ndarray, ...]] = None,
#         episode_start: Optional[np.ndarray] = None,
#         deterministic: bool = False,
#     ) -> Tuple[np.ndarray, Optional[Tuple[np.ndarray, ...]]]:
#         """
#         Get the policy action from an observation (and optional hidden state).
#         Includes sugar-coating to handle different observations (e.g. normalizing images).
#
#         :param observation: the input observation
#         :param state: The last hidden states (can be None, used in recurrent policies)
#         :param episode_start: The last masks (can be None, used in recurrent policies)
#             this correspond to beginning of episodes,
#             where the hidden states of the RNN must be reset.
#         :param deterministic: Whether or not to return deterministic actions.
#         :return: the model's action and the next hidden state
#             (used in recurrent policies)
#         """
#         return self.policy.predict(observation, state, episode_start, deterministic)
# File:      /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/base_class.py
# Type:      method

# %%
env.action_space.sample()
# Out:
# 1

# %%
env.step(action)
# Out:
# (array([[ 0.0215057 , -0.1806088 , -0.03177781,  0.3085903 ]],
#        dtype=float32),
#  array([1.], dtype=float32),
#  array([False]),
#  [{'TimeLimit.truncated': False}])

# %% [markdown]
# # Viewing Logs in a Tensorboard

# %%
training_log_path = os.path.join(log_path,'PPO_4')

# %%
# %pip install tensorboard
# Out:
# Requirement already satisfied: tensorboard in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.17.0)
# Requirement already satisfied: absl-py>=0.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from tensorboard) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from tensorboard) (1.62.1)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from tensorboard) (3.6)
# Requirement already satisfied: numpy>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from tensorboard) (1.26.4)
# Requirement already satisfied: protobuf!=4.24.0,<5.0.0,>=3.19.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from tensorboard) (4.25.4)
# Requirement already satisfied: setuptools>=41.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from tensorboard) (69.2.0)
# Requirement already satisfied: six>1.9 in /Users/meghnapusala/Library/Python/3.12/lib/python/site-packages (from tensorboard) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from tensorboard) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from tensorboard) (3.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.5)
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# I0807 02:53:54.994399 14473818112 plugin.py:429] Monitor runs begin
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.17.0 at http://localhost:6006/ (Press CTRL+C to quit)
# W0807 02:54:23.750689 14507470848 application.py:559] path /apple-touch-icon-precomposed.png not found, sending 404
# W0807 02:54:23.810138 14507470848 application.py:559] path /apple-touch-icon.png not found, sending 404
# ^C

# %% [markdown]
# # Adding Callbacks

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
env = gym.make(env_name)
env = DummyVecEnv([lambda: env])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, 
                             best_model_save_path=model_path, 
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to training/logs/PPO_5
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -----------------------------
# | time/              |      |
# |    fps             | 4982 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3190        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009154245 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.0081     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.94        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 45.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2954        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010704955 |
# |    clip_fraction        | 0.0687      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.1         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 40.3        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2869       |
# |    iterations           | 4          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.00878256 |
# |    clip_fraction        | 0.105      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.632     |
# |    explained_variance   | 0.271      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 23.2       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0223    |
# |    value_loss           | 53.9       |
# ----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.007626485 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.605      |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 60.3        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 200.00  is above the threshold 190
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
best_model_path = os.path.join(model_path, 'best_model')
model = PPO.load(best_model_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (197.0, 9.0)

# %%
env.close()

# %% [markdown]
# # Changing Policy

# %%
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/policies.py:486: UserWarning: As shared layers in the mlp_extractor are removed since SB3 v1.8.0, you should now pass directly a dictionary and not a list (net_arch=dict(pi=..., vf=...) instead of net_arch=[dict(pi=..., vf=...)])
#   warnings.warn(

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 4338 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2523        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015269836 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.681      |
# |    explained_variance   | -0.00634    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0283     |
# |    value_loss           | 20.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2216        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012863141 |
# |    clip_fraction        | 0.147       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.65       |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.84        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0291     |
# |    value_loss           | 30.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2101        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011130586 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.608      |
# |    explained_variance   | 0.331       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 47.6        |
# -----------------------------------------
# Eval num_timesteps=10000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.010234978 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.577      |
# |    explained_variance   | 0.58        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 39.5        |
# -----------------------------------------
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# ------------------------------
# | time/              |       |
# |    fps             | 1980  |
# |    iterations      | 5     |
# |    time_elapsed    | 5     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1943        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013661968 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.546      |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.81        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0078     |
# |    value_loss           | 20.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1929        |
# |    iterations           | 7           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.004469797 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.511      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.698       |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00233    |
# |    value_loss           | 9.85        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1921        |
# |    iterations           | 8           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009824611 |
# |    clip_fraction        | 0.0575      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.482      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.205       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | 0.00106     |
# |    value_loss           | 6.05        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1915         |
# |    iterations           | 9            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0051116655 |
# |    clip_fraction        | 0.0563       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.48        |
# |    explained_variance   | 0.744        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.773        |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00102     |
# |    value_loss           | 4.51         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=200.00 +/- 0.00
# Episode length: 200.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 200         |
# |    mean_reward          | 200         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.005987916 |
# |    clip_fraction        | 0.0527      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.469      |
# |    explained_variance   | -0.053      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.343       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | 0.000402    |
# |    value_loss           | 3.23        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1884  |
# |    iterations      | 10    |
# |    time_elapsed    | 10    |
# |    total_timesteps | 20480 |
# ------------------------------

# %% [markdown]
# # Using Alternate Algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to training/logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 14438    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.922    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 5157     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 165      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.494    |
# |    n_updates        | 16       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.891    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4596     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 230      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.483    |
# |    n_updates        | 32       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4513     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 318      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.448    |
# |    n_updates        | 54       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4380     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 413      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.362    |
# |    n_updates        | 78       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4252     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 500      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.349    |
# |    n_updates        | 99       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.728    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4184     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 573      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.274    |
# |    n_updates        | 118      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.701    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4146     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 629      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.253    |
# |    n_updates        | 132      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.671    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4097     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 693      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.247    |
# |    n_updates        | 148      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.634    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 
|
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000117 |
# |    n_updates        | 1067     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 3142     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4430     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000141 |
# |    n_updates        | 1082     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 3142     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4479     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00051  |
# |    n_updates        | 1094     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 3136     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4534     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000502 |
# |    n_updates        | 1108     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 3135     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4589     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000494 |
# |    n_updates        | 1122     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 3134     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4638     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000357 |
# |    n_updates        | 1134     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 3134     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4694     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000248 |
# |    n_updates        | 1148     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 3135     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4760     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000181 |
# |    n_updates        | 1164     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 3139     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4825     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000887 |
# |    n_updates        | 1181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 3141     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4885     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000307 |
# |    n_updates        | 1196     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 3136     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 4946     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000349 |
# |    n_updates        | 1211     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 3134     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5014     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000483 |
# |    n_updates        | 1228     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 3138     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5082     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000149 |
# |    n_updates        | 1245     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 3141     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5133     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000227 |
# |    n_updates        | 1258     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 3143     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5177     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00045  |
# |    n_updates        | 1269     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 3142     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5222     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00168  |
# |    n_updates        | 1280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 3144     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5271     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000198 |
# |    n_updates        | 1292     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 3140     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5333     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000599 |
# |    n_updates        | 1308     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 3144     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5402     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00156  |
# |    n_updates        | 1325     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 3138     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5454     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000698 |
# |    n_updates        | 1338     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 3139     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5505     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.61e-05 |
# |    n_updates        | 1351     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 3139     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5549     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000878 |
# |    n_updates        | 1362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 3141     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5593     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000269 |
# |    n_updates        | 1373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 3138     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5638     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000369 |
# |    n_updates        | 1384     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 3134     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 5677     |
# | train/              |          |
# ...
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1776     |
# |    fps              | 2804     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 18726    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00649  |
# |    n_updates        | 4656     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1780     |
# |    fps              | 2805     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 18765    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 4666     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1784     |
# |    fps              | 2805     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 18805    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00388  |
# |    n_updates        | 4676     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1788     |
# |    fps              | 2805     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 18844    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0118   |
# |    n_updates        | 4685     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1792     |
# |    fps              | 2805     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 18880    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0379   |
# |    n_updates        | 4694     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1796     |
# |    fps              | 2804     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 18918    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 4704     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1800     |
# |    fps              | 2805     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 18958    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.036    |
# |    n_updates        | 4714     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1804     |
# |    fps              | 2805     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 18995    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0184   |
# |    n_updates        | 4723     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1808     |
# |    fps              | 2790     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19031    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 4732     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1812     |
# |    fps              | 2790     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19069    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00415  |
# |    n_updates        | 4742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1816     |
# |    fps              | 2791     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19105    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 4751     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1820     |
# |    fps              | 2791     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19143    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0257   |
# |    n_updates        | 4760     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1824     |
# |    fps              | 2791     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19183    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 4770     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1828     |
# |    fps              | 2792     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19219    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0135   |
# |    n_updates        | 4779     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1832     |
# |    fps              | 2792     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19255    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0624   |
# |    n_updates        | 4788     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1836     |
# |    fps              | 2791     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19292    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0335   |
# |    n_updates        | 4797     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1840     |
# |    fps              | 2791     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19328    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.03     |
# |    n_updates        | 4806     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1844     |
# |    fps              | 2790     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19365    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0261   |
# |    n_updates        | 4816     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1848     |
# |    fps              | 2791     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19404    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0182   |
# |    n_updates        | 4825     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1852     |
# |    fps              | 2792     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19443    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 4835     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1856     |
# |    fps              | 2791     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 19483    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 4845     |
# ----------------------------------
# Eval num_timesteps=19520, episode_reward=9.60 +/- 0.80
# Episode length: 9.60 +/- 0.80
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 9.6      |
# |    mean_reward      | 9.6      |
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    total_timesteps  | 19520    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0282   |
# |    n_updates        | 4854     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1860     |
# |    fps              | 2788     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19530    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 4857     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1864     |
# |    fps              | 2788     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19570    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 4867     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1868     |
# |    fps              | 2788     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19607    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0253   |
# |    n_updates        | 4876     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1872     |
# |    fps              | 2787     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19642    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0172   |
# |    n_updates        | 4885     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1876     |
# |    fps              | 2787     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19679    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0102   |
# |    n_updates        | 4894     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1880     |
# |    fps              | 2787     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19721    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 4905     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1884     |
# |    fps              | 2788     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19761    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0149   |
# |    n_updates        | 4915     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1888     |
# |    fps              | 2788     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00931  |
# |    n_updates        | 4924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1892     |
# |    fps              | 2788     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19838    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0324   |
# |    n_updates        | 4934     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1896     |
# |    fps              | 2788     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19875    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0299   |
# |    n_updates        | 4943     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1900     |
# |    fps              | 2786     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19916    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.028    |
# |    n_updates        | 4953     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1904     |
# |    fps              | 2786     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19955    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 4963     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1908     |
# |    fps              | 2786     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 19993    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0197   |
# |    n_updates        | 4973     |
# ----------------------------------

# %%
dqn_path = os.path.join(model_path, 'DQN_model')

# %%
model.save(dqn_path)

# %%
model = DQN.load(dqn_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# (9.6, 0.7999999999999999)

# %%
env.close()
